# %% [markdown]
# # Indexing

# %%
import pandas as pd

# %%
df = pd.read_csv('../olympics.csv', skiprows=4)
df.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
# Set the new index to a variable 'athlete'
athlete = df.set_index('Athlete')
athlete.head()
# Out:
#                       City  Edition     Sport Discipline  NOC Gender  \
# Athlete
# HAJOS, Alfred       Athens     1896  Aquatics   Swimming  HUN    Men
# HERSCHMANN, Otto    Athens     1896  Aquatics   Swimming  AUT    Men
# DRIVAS, Dimitrios   Athens     1896  Aquatics   Swimming  GRE    Men
# MALOKINIS, Ioannis  Athens     1896  Aquatics   Swimming  GRE    Men
# CHASAPIS, Spiridon  Athens     1896  Aquatics   Swimming  GRE    Men
#
#                                          Event Event_gender   Medal
# Athlete
# HAJOS, Alfred                   100m freestyle            M    Gold
# HERSCHMANN, Otto                100m freestyle            M  Silver
# DRIVAS, Dimitrios   100m freestyle for sailors            M  Bronze
# MALOKINIS, Ioannis  100m freestyle for sailors            M    Gold
# CHASAPIS, Spiridon  100m freestyle for sailors            M  Silver

# %% [markdown]
# ## loc[...]

# %%
df.loc['BOLT, Usain']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df.loc['BOLT, Usain']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1393, in _LocIndexer._getitem_axis(self, key, axis)
#    1391 # fall thru to straight lookup
#    1392 self._validate_key(key, axis)
# -> 1393 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._get_label(self, label, axis)
#    1341 def _get_label(self, label, axis: AxisInt):
#    1342     # GH#5567 this will fail if the label is not present in the axis.
# ...

# %%
df.reset_index(inplace=True)
df.head()
# Out:
#    index    City  Edition     Sport Discipline             Athlete  NOC  \
# 0      0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN
# 1      1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2      2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3      3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4      4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
df.set_index('Athlete', inplace=True)

# %%
df.loc['BOLT, Usain']
# Out:
#              index     City  Edition      Sport Discipline  NOC Gender  \
# Athlete
# BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
#
#                     Event Event_gender Medal
# Athlete
# BOLT, Usain          100m            M  Gold
# BOLT, Usain          200m            M  Gold
# BOLT, Usain  4x100m relay            M  Gold

# %%
df.reset_index(inplace=True)

# %%
df[df.Athlete == 'BOLT, Usain']
# Out:
#            Athlete  index     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %%
df.loc[df.Athlete == 'BOLT, Usain']
# Out:
#            Athlete  index     City  Edition      Sport Discipline  NOC Gender  \
# 27552  BOLT, Usain  27552  Beijing     2008  Athletics  Athletics  JAM    Men
# 27570  BOLT, Usain  27570  Beijing     2008  Athletics  Athletics  JAM    Men
# 27603  BOLT, Usain  27603  Beijing     2008  Athletics  Athletics  JAM    Men
#
#               Event Event_gender Medal
# 27552          100m            M  Gold
# 27570          200m            M  Gold
# 27603  4x100m relay            M  Gold

# %% [markdown]
# ## iloc[...]

# %%
df.head()
# Out:
#               Athlete  index    City  Edition     Sport Discipline  NOC  \
# 0       HAJOS, Alfred      0  Athens     1896  Aquatics   Swimming  HUN
# 1    HERSCHMANN, Otto      1  Athens     1896  Aquatics   Swimming  AUT
# 2   DRIVAS, Dimitrios      2  Athens     1896  Aquatics   Swimming  GRE
# 3  MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE
# 4  CHASAPIS, Spiridon      4  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %%
df.iloc[1700]
# Out:
# Athlete         RABOT, Pierre
# index                    1700
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %%
df.iloc[[1542, 2390, 6000, 15000]]
# Out:
#                         Athlete  index         City  Edition       Sport  \
# 1542     DUCKETT, Richard Louis   1542       London     1908    Lacrosse
# 2390         SAASTAMOINEN, Eino   2390    Stockholm     1912  Gymnastics
# 6000            AGOSTONI, Carlo   6000  Los Angeles     1932     Fencing
# 15000  JENSEN, Poul Richard Hoj  15000     Montreal     1976     Sailing
#
#         Discipline  NOC Gender                                    Event  \
# 1542      Lacrosse  CAN    Men                                 lacrosse
# 2390   Artistic G.  FIN    Men                        team, free system
# 6000       Fencing  ITA    Men                          épée individual
# 15000      Sailing  DEN    Men  fleet/match race keelboat open (Soling)
#
#       Event_gender   Medal
# 1542             M    Gold
# 2390             M  Silver
# 6000             M  Bronze
# 15000            X    Gold

# %%
df.iloc[1:4]
# Out:
#               Athlete  index    City  Edition     Sport Discipline  NOC  \
# 1    HERSCHMANN, Otto      1  Athens     1896  Aquatics   Swimming  AUT
# 2   DRIVAS, Dimitrios      2  Athens     1896  Aquatics   Swimming  GRE
# 3  MALOKINIS, Ioannis      3  Athens     1896  Aquatics   Swimming  GRE
#
#   Gender                       Event Event_gender   Medal
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
